# %% [markdown]
# # Initiative Personal Project 2
#
# ## at Generasi GIGIH - Data Analyst Batch 1

# %% [markdown]
# # Exploratory Data Analysis_GooglePlaystore

# %% [markdown]
# ## By Ghazali Akmal Rabbani

# %% [markdown]
# # Data Extraction

# %%
import pandas as pd
import numpy as np
import scipy
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('googleplaystore.csv')
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# # Information Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# Based on the summary information in the above, there are **1 columns with float type (float64)** which denotes **Numerical Column** and **11 columns with object type** which denotes **Categorical Column**. And also there are **10841 data**

# %% [markdown]
# ## Check Null Values

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %% [markdown]
# ## Get data which contain Null values in Rating column

# %%
RatingNull = df[df['Rating'].isnull()]
RatingNull
# Out:
#                                        App             Category  Rating  \
# 23                  Mcqueen Coloring pages       ART_AND_DESIGN     NaN
# 113              Wrinkles and rejuvenation               BEAUTY     NaN
# 123                 Manicure - nail design               BEAUTY     NaN
# 126           Skin Care and Natural Beauty               BEAUTY     NaN
# 129    Secrets of beauty, youth and health               BEAUTY     NaN
# ...                                    ...                  ...     ...
# 10824                            Cardio-FR              MEDICAL     NaN
# 10825                   Naruto & Boruto FR               SOCIAL     NaN
# 10831             payermonstationnement.fr  MAPS_AND_NAVIGATION     NaN
# 10835                             FR Forms             BUSINESS     NaN
# 10838               Parkinson Exercices FR              MEDICAL     NaN
#
#       Reviews  Size  Installs  Type Price Content Rating  \
# ...

# %% [markdown]
# ## Get data which contain Null values in Type column

# %%
TypeNull = df[df['Type'].isnull()]
TypeNull
# Out:
#                             App Category  Rating Reviews                Size  \
# 9148  Command & Conquer: Rivals   FAMILY     NaN       0  Varies with device
#
#      Installs Type Price Content Rating    Genres   Last Updated  \
# 9148        0  NaN     0   Everyone 10+  Strategy  June 28, 2018
#
#              Current Ver         Android Ver
# 9148  Varies with device  Varies with device

# %% [markdown]
# ## Get data which contain Null values in Content Rating column

# %%
ContentRatingNull = df[df['Content Rating'].isnull()]
ContentRatingNull
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %% [markdown]
# ## Get data which contain Null values in Current Ver column

# %%
CurrentVerNull = df[df['Current Ver'].isnull()]
CurrentVerNull
# Out:
#                                    App             Category  Rating Reviews  \
# 15     Learn To Draw Kawaii Characters       ART_AND_DESIGN     3.2      55
# 1553              Market Update Helper   LIBRARIES_AND_DEMO     4.1   20145
# 6322            Virtual DJ Sound Mixer                TOOLS     4.2    4010
# 6803                         BT Master               FAMILY     NaN       0
# 7333                       Dots puzzle               FAMILY     4.0     179
# 7407                   Calculate My IQ               FAMILY     NaN      44
# 7730                            UFO-CQ                TOOLS     NaN       1
# 10342                   La Fe de Jesus  BOOKS_AND_REFERENCE     NaN       8
#
#        Size    Installs  Type  Price Content Rating             Genres  \
# 15     2.7M      5,000+  Free      0       Everyone       Art & Design
# 1553    11k  1,000,000+  Free      0       Everyone   Libraries & Demo
# ...

# %% [markdown]
# ## Get data which contain Null values in Android Ver column

# %%
AndroidVerNull = df[df['Android Ver'].isnull()]
AndroidVerNull
# Out:
#                                            App         Category  Rating  \
# 4453                    [substratum] Vacuum: P  PERSONALIZATION     4.4
# 4490                      Pi Dark [substratum]  PERSONALIZATION     4.5
# 10472  Life Made WI-Fi Touchscreen Photo Frame              1.9    19.0
#
#       Reviews    Size Installs  Type     Price Content Rating  \
# 4453      230     11M   1,000+  Paid     $1.49       Everyone
# 4490      189    2.1M  10,000+  Free         0       Everyone
# 10472    3.0M  1,000+     Free     0  Everyone            NaN
#
#                   Genres    Last Updated Current Ver Android Ver
# 4453     Personalization   July 20, 2018         4.4         NaN
# 4490     Personalization  March 27, 2018         1.1         NaN
# 10472  February 11, 2018          1.0.19  4.0 and up         NaN

# %% [markdown]
# ## Call to Action for Null Values in the columns

# %% [markdown]
# Based on the result in above, I will take general assumption to Null values in Android Ver, Current Ver, Content Rating, and Type column that every data which have Null values in those column will be **DELETED** in order to resist the meaning of Dataframe in a whole.
#
# And then replace to **Zero(0.0)** value to every Null values in Rating column. Because I assume that if every data which has Null value, it is same like it doesn't have any review

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Replace Null values in Rating column to Zero float values (0.0)

# %%
df['Rating'] = df['Rating'].fillna(0)

# %%
df.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              1
# Price             0
# Content Rating    1
# Genres            0
# Last Updated      0
# Current Ver       8
# Android Ver       3
# dtype: int64

# %% [markdown]
# ## Drop Null values
#
# Drop Null values in Android Ver, Current Ver, Content Rating, and Type column

# %%
# Drop Null values of all column in one code
df = df.dropna(axis = 0, how ='any')

# Recheck the Null Data
df.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %% [markdown]
# ## Re-checking the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10829 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10829 non-null  object
#  1   Category        10829 non-null  object
#  2   Rating          10829 non-null  float64
#  3   Reviews         10829 non-null  object
#  4   Size            10829 non-null  object
#  5   Installs        10829 non-null  object
#  6   Type            10829 non-null  object
#  7   Price           10829 non-null  object
#  8   Content Rating  10829 non-null  object
#  9   Genres          10829 non-null  object
#  10  Last Updated    10829 non-null  object
#  11  Current Ver     10829 non-null  object
#  12  Android Ver     10829 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.2+ MB

# %%
df['Rating'].value_counts()
# Out:
# 0.0    1469
# 4.4    1108
# 4.3    1076
# 4.5    1037
# 4.2     951
# 4.6     823
# 4.1     707
# 4.0     567
# 4.7     499
# 3.9     386
# 3.8     303
# 5.0     274
# 3.7     239
# 4.8     234
# 3.6     174
# 3.5     163
# 3.4     128
# 3.3     102
# 4.9      87
# 3.0      83
# 3.1      69
# 3.2      63
# 2.9      45
# 2.8      42
# 2.6      25
# 2.7      25
# 2.5      21
# 2.3      20
# 2.4      19
# 1.0      16
# 2.2      14
# 1.9      13
# 2.0      12
# 1.7       8
# 1.8       8
# 2.1       8
# 1.6       4
# 1.5       3
# 1.4       3
# 1.2       1
# Name: Rating, dtype: int64

# %%
df['Size'].value_counts()
# Out:
# Varies with device    1694
# 11M                    197
# 12M                    196
# 14M                    193
# 13M                    191
#                       ...
# 200k                     1
# 511k                     1
# 982k                     1
# 82k                      1
# 861k                     1
# Name: Size, Length: 457, dtype: int64

# %%
df['Installs'].value_counts()
# Out:
# 1,000,000+        1578
# 10,000,000+       1252
# 100,000+          1169
# 10,000+           1052
# 1,000+             905
# 5,000,000+         752
# 100+               718
# 500,000+           538
# 50,000+            478
# 5,000+             476
# 100,000,000+       409
# 10+                385
# 500+               330
# 50,000,000+        289
# 50+                205
# 5+                  82
# 500,000,000+        72
# 1+                  67
# 1,000,000,000+      58
# 0+                  14
# Name: Installs, dtype: int64

# %%
df['Reviews'].value_counts()
# Out:
# 0         594
# 1         271
# 2         214
# 3         175
# 4         137
#          ...
# 951         1
# 2962        1
# 906384      1
# 36969       1
# 5988        1
# Name: Reviews, Length: 5999, dtype: int64

# %% [markdown]
# # Statistical Numerical Analysis

# %%
df.describe()
# Out:
#              Rating
# count  10829.000000
# mean       3.623197
# std        1.513263
# min        0.000000
# 25%        3.700000
# 50%        4.200000
# 75%        4.500000
# max        5.000000

# %% [markdown]
# # Statistical Categorical Analysis

# %% [markdown]
# ## Convert type of Rating column to categorical data

# %%
# Now we will convert Rating column from 
# 'float' to 'String' type. 
df['Rating'] = df['Rating'].astype(str)

#Re-check the type of data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10829 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10829 non-null  object
#  1   Category        10829 non-null  object
#  2   Rating          10829 non-null  object
#  3   Reviews         10829 non-null  object
#  4   Size            10829 non-null  object
#  5   Installs        10829 non-null  object
#  6   Type            10829 non-null  object
#  7   Price           10829 non-null  object
#  8   Content Rating  10829 non-null  object
#  9   Genres          10829 non-null  object
#  10  Last Updated    10829 non-null  object
#  11  Current Ver     10829 non-null  object
#  12  Android Ver     10829 non-null  object
# dtypes: object(13)
# memory usage: 1.2+ MB

# %% [markdown]
# ## Do Statistical Categorical Analysis

# %%
df.describe()
# Out:
#            App Category Rating Reviews                Size    Installs   Type  \
# count    10829    10829  10829   10829               10829       10829  10829
# unique    9648       33     40    5999                 457          20      2
# top     ROBLOX   FAMILY    0.0       0  Varies with device  1,000,000+   Free
# freq         9     1968   1469     594                1694        1578  10032
#
#         Price Content Rating Genres    Last Updated         Current Ver  \
# count   10829          10829  10829           10829               10829
# unique     92              6    119            1376                2831
# top         0       Everyone  Tools  August 3, 2018  Varies with device
# freq    10032           8704    840             326                1458
#
#        Android Ver
# count        10829
# unique          33
# top     4.1 and up
# freq          2451

# %% [markdown]
# # Barplot Function

# %%
def barplot_maindf(data):
    barplot_data = df[data].value_counts().rename_axis('unique_values').reset_index(name='counts')

    plt.figure(figsize = (15, 8))
    ax = sns.barplot(
        x = 'unique_values',
        y = 'counts',
        data = barplot_data,
        
    )
    plt.title( data.capitalize() + ' Count', fontsize = 18, fontweight = 'bold')
    plt.xlabel(data.capitalize(), fontsize = 15, fontweight = 'bold')
    plt.ylabel('Total', fontsize = 15, fontweight = 'bold')
    plt.tight_layout()

    for x in ax.patches:
        ax.annotate(
                format(x.get_height(), '.0f'),
                (x.get_x() + x.get_width() / 2., x.get_height()), 
                ha = 'center',
                va = 'center',
                fontweight = 'bold',
                size = 13,
                xytext = (0, 7), 
                textcoords = 'offset points'
        )

    plt.figure(figsize=(15,8))
    largest5 = barplot_data.nlargest(10,'counts')
    ax = sns.barplot(
        x = 'unique_values',
        y = 'counts',
        data = largest5,
        order = largest5['unique_values']
    )

    plt.title( data.capitalize() + ' Count Top 10', fontsize = 18, fontweight = 'bold')
    plt.xlabel(data.capitalize(), fontsize = 15, fontweight = 'bold')
    plt.ylabel('Total', fontsize = 15, fontweight = 'bold')
    plt.tight_layout()

    for x in ax.patches:
        ax.annotate(
                format(x.get_height(), '.0f'),
                (x.get_x() + x.get_width() / 2., x.get_height()), 
                ha = 'center',
                va = 'center',
                fontweight = 'bold',
                size = 13,
                xytext = (0, 7), 
                textcoords = 'offset points'
        )
    
    plt.figure(figsize=(15,8))
    smallest5 = barplot_data.nsmallest(10,'counts')
    ax = sns.barplot(
        x = 'unique_values',
        y = 'counts',
        data = smallest5,
        order = smallest5['unique_values']
    )

    plt.title( data.capitalize() + ' Count Least 10', fontsize = 18, fontweight = 'bold')
    plt.xlabel(data.capitalize(), fontsize = 15, fontweight = 'bold')
    plt.ylabel('Total', fontsize = 15, fontweight = 'bold')
    plt.tight_layout()

    for x in ax.patches:
        ax.annotate(
                format(x.get_height(), '.0f'),
                (x.get_x() + x.get_width() / 2., x.get_height()), 
                ha = 'center',
                va = 'center',
                fontweight = 'bold',
                size = 13,
                xytext = (0, 7), 
                textcoords = 'offset points'
        )

# %% [markdown]
# ## Get list of Categorical column

# %%
dfCategoricalColumn = df.select_dtypes(include=['object']).columns.tolist()
dfCategoricalColumn
# Out:
# ['App',
#  'Category',
#  'Rating',
#  'Reviews',
#  'Size',
#  'Installs',
#  'Type',
#  'Price',
#  'Content Rating',
#  'Genres',
#  'Last Updated',
#  'Current Ver',
#  'Android Ver']

# %% [markdown]
# ## App Visualization

# %%
barplot_maindf(dfCategoricalColumn[0])

# %% [markdown]
# ## Category Visualization

# %%
barplot_maindf(dfCategoricalColumn[1])

# %% [markdown]
# ## Rating Visualization

# %%
barplot_maindf(dfCategoricalColumn[2])

# %% [markdown]
# ## Reviews Visualization

# %%
barplot_maindf(dfCategoricalColumn[3])

# %% [markdown]
# ## Size Visualization

# %%
barplot_maindf(dfCategoricalColumn[4])

# %% [markdown]
# ## Installs Visualization

# %%
barplot_maindf(dfCategoricalColumn[5])

# %% [markdown]
# ## Type Visualization

# %%
barplot_maindf(dfCategoricalColumn[6])

# %% [markdown]
# ## Price Visualization

# %%
barplot_maindf(dfCategoricalColumn[7])

# %% [markdown]
# ## Content Rating Visualization

# %%
barplot_maindf(dfCategoricalColumn[8])

# %% [markdown]
# ## Genres Visualization

# %%
barplot_maindf(dfCategoricalColumn[9])

# %% [markdown]
# ## Last Updated Visualization

# %%
barplot_maindf(dfCategoricalColumn[10])

# %% [markdown]
# ## Current Ver Visualization

# %%
barplot_maindf(dfCategoricalColumn[11])

# %% [markdown]
# ## Android Ver Visualization

# %%
barplot_maindf(dfCategoricalColumn[12])
